# %% [markdown]
# # Module 1 title
#
# Replace this placeholder with the module title and teaching content used to provide scoring context.

# %% [markdown]
# ## Learning objectives
#
# - Replace this item with a module learning objective.

# %% [markdown]
# ## Key course content
#
# Replace this placeholder with the instructional material that the model should use to understand the module.
